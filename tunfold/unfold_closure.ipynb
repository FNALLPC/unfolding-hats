# %%
#!/usr/bin/env python

import math
import sys

from ROOT import TH1, TH1F, TH2F, TFile, TCanvas, TPad, TLegend, TLatex, TColor, TMath, TVectorD, TGraph, TUnfold, Double, TSpline, TSpline3, TUnfoldDensity, TUnfoldSys, TAttLine, TStyle

from array import array
import string

from plotting import *
# Out:
# Welcome to JupyROOT 6.10/09

# %%
# -------------------------------------------------------------------------------------
# Get nominal response matrix
# -------------------------------------------------------------------------------------
unfolding_input = TFile("../data/unfolding_input.root")
response = unfolding_input.Get("response")

# %%
# -------------------------------------------------------------------------------------
# Draw response matrix
# -------------------------------------------------------------------------------------

c1 = TCanvas("c1", "", 800, 600)
c1.SetTopMargin(0.07)
c1.SetRightMargin(0.15)
c1.SetBottomMargin(0.15)
c1.SetLeftMargin(0.15)

response_norm = response.Clone("response_norm")

for ibiny in xrange(1,response_norm.GetNbinsY()+1):
    tmp = response_norm.Integral(0,response_norm.GetNbinsX()+1,ibiny,ibiny)
    for ibinx in xrange(1,response_norm.GetNbinsX()+1):
        response_norm.SetBinContent(ibinx,ibiny,response_norm.GetBinContent(ibinx,ibiny)/tmp)    

response_norm.SetTitle(";reconstructed top jet p_{T} [GeV];true top quark p_{T} [GeV]")
response_norm.GetZaxis().SetRangeUser(0.0,0.035)
response_norm.Draw("colz")

c1.Draw()

# %%
# -------------------------------------------------------------------------------------
# Get data distribution
# -------------------------------------------------------------------------------------

measurement = unfolding_input.Get("measured_MC")

# %%
# -------------------------------------------------------------------------------------
# Get true distribution
# -------------------------------------------------------------------------------------

expectation = unfolding_input.Get("expected")

# %%
# -------------------------------
# Remove fakes from input
# -------------------------------

for ii in xrange(1,response.GetNbinsX()+1):
    if response.Integral(ii,ii,0,response.GetNbinsY()+1) > 0.0 :
        fakefraction = response.GetBinContent(ii,0) / response.Integral(ii,ii,0,response.GetNbinsY()+1)
        measurement.SetBinContent(ii,measurement.GetBinContent(ii)*(1.0-fakefraction))
        measurement.SetBinError(ii,measurement.GetBinError(ii)*(1.0-fakefraction))
        response.SetBinContent(ii,0,0)
        response.SetBinError(ii,0,0)

# %%
# -------------------------------------------------------------------------------------
# Do unfolding
# -------------------------------------------------------------------------------------

# %jsroot off

unfold = TUnfoldDensity(response,TUnfold.kHistMapOutputVert, TUnfold.kRegModeCurvature, TUnfold.kEConstraintArea, TUnfoldDensity.kDensityModeBinWidth)
unfold.SetInput(measurement)

# Do unfolding using LCurve to determine regularization strength
#cc = TCanvas("cc", "cc", 700, 700)
#cc.cd()
#logTauX = TSpline3()
#logTauY = TSpline3()
#lCurve = TGraph()
#bestLCurve = TGraph(1)
#iBest = unfold.ScanLcurve(30,0.,0.,lCurve,logTauX,logTauY)
#Tau = Double(0)
#x = Double(0)
#y = Double(0)
#logTauX.GetKnot(iBest,Tau,x)
#logTauY.GetKnot(iBest,Tau,y)
#bestLCurve.SetPoint(1,x,y)
#bestLCurve.SetMarkerColor(2)
#lCurve.GetXaxis().SetTitle("log L_{1}")
#lCurve.GetYaxis().SetTitle("log L_{2} / #tau^{2}")
#lCurve.Draw()
#bestLCurve.Draw("*")
#tl2 = TLatex()
#tl2.SetNDC()
#tl2.SetTextFont(42)
#legend = "log(#tau) = %.3e" % Tau
#tl2.DrawLatex(0.55,0.8,legend)
#cc.SaveAs("lcurve_scan.pdf")

# Do unfolding using ScanTau to determine regularization strength
cc = TCanvas("cc", "cc", 700, 700)
cc.cd()
bestTau = TGraph(1)
scanResult = TSpline3()
iBest = unfold.ScanTau(100,0.0001,0.1,scanResult,TUnfoldDensity.kEScanTauRhoAvgSys)
Tau = Double(0)
rho = Double(0)
scanResult.GetKnot(iBest,Tau,rho)
bestTau.SetPoint(1,Tau,rho)
bestTau.SetMarkerColor(2)
scanResult.Draw("P")
bestTau.Draw("*")
tl2 = TLatex()
tl2.SetNDC()
tl2.SetTextFont(42)
legend = "log(#tau) = %.3e" % Tau
tl2.DrawLatex(0.55,0.8,legend)
cc.Draw()

# Do non-regularized unfolding
#unfold.DoUnfold(0)
# Out:
# Info in <TUnfold::SetConstraint>: fConstraint=1
# Info in <TUnfold::TUnfold>: underflow and overflow bin do not depend on the input data
# Info in <TUnfold::TUnfold>: 14 input bins and 7 output bins
# Info in <TUnfoldDensity::TUnfold>: *NOT* unfolding bin #0 (yaxis:p_{T}(generated top) [GeV][ufl])
# Info in <TUnfoldDensity::TUnfold>: *NOT* unfolding bin #8 (yaxis:p_{T}(generated top) [GeV][ofl])
# Info in <TUnfoldDensity::RegularizeOneDistribution>: regularizing yaxis regMode=3 densityMode=1 axisSteering=*[UOB]
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.000000 y=0.735736 X=2.515305 Y=4.867814
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-4.000000 y=0.741121 X=-7.897841 Y=5.429750
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.500000 y=0.739913 X=-1.904522 Y=5.425697
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.250000 y=0.741083 X=-4.898047 Y=5.429625
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.750000 y=0.704257 X=0.913937 Y=5.324021
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.625000 y=0.741115 X=-6.397873 Y=5.429731
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.875000 y=0.740907 X=-3.399028 Y=5.429029
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.125000 y=0.734356 X=-0.434733 Y=5.407641
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.375000 y=0.605766 X=1.884277 Y=5.111827
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.812500 y=0.741119 X=-7.147851 Y=5.429744
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.437500 y=0.741106 X=-5.647924 Y=5.429700
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.062500 y=0.741031 X=-4.148338 Y=5.429448
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.687500 y=0.740612 X=-2.650661 Y=5.428036
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.312500 y=0.738259 X=-1.163602 Y=5.420222
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.937500 y=0.725215 X=0.267284 Y=5.379895
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.562500 y=0.659846 X=1.463131 Y=5.230144
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.187500 y=0.665503 X=2.207264 Y=4.994659
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.906250 y=0.741120 X=-7.522845 Y=5.429748
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.718750 y=0.741117 X=-6.772859 Y=5.429739
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.531250 y=0.741111 X=-6.022893 Y=5.429719
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.343750 y=0.741097 X=-5.272973 Y=5.429670
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.156250 y=0.741063 X=-4.523162 Y=5.429555
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.968750 y=0.740982 X=-3.773610 Y=5.429283
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.781250 y=0.740790 X=-3.024672 Y=5.428637
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.593750 y=0.740336 X=-2.277183 Y=5.427113
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.406250 y=0.739261 X=-1.533109 Y=5.423529
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.218750 y=0.736719 X=-0.796988 Y=5.415203
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.031250 y=0.730737 X=-0.078971 Y=5.396379
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.843750 y=0.716835 X=0.599960 Y=5.356373
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.656250 y=0.685768 X=1.203448 Y=5.281752
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.093750 y=0.706197 X=2.359016 Y=4.934328
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.468750 y=0.628109 X=1.689766 Y=5.172060
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.281250 y=0.622612 X=2.053055 Y=5.052728
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.953125 y=0.741120 X=-7.710343 Y=5.429749
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.859375 y=0.741119 X=-7.335348 Y=5.429746
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.765625 y=0.741118 X=-6.960355 Y=5.429742
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.671875 y=0.741116 X=-6.585365 Y=5.429736
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.578125 y=0.741113 X=-6.210382 Y=5.429726
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.484375 y=0.741109 X=-5.835407 Y=5.429710
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.390625 y=0.741102 X=-5.460446 Y=5.429687
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.296875 y=0.741091 X=-5.085506 Y=5.429650
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.203125 y=0.741074 X=-4.710598 Y=5.429594
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.109375 y=0.741049 X=-4.335741 Y=5.429507
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.015625 y=0.741009 X=-3.960960 Y=5.429374
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.921875 y=0.740948 X=-3.586297 Y=5.429169
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.828125 y=0.740855 X=-3.211815 Y=5.428854
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.734375 y=0.740711 X=-2.837613 Y=5.428369
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.640625 y=0.740489 X=-2.463841 Y=5.427624
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.546875 y=0.740147 X=-2.090728 Y=5.426480
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.453125 y=0.739622 X=-1.718624 Y=5.424728
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.359375 y=0.738814 X=-1.348065 Y=5.422049
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.265625 y=0.737571 X=-0.979855 Y=5.417972
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.171875 y=0.735663 X=-0.615201 Y=5.411803
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.078125 y=0.732738 X=-0.255875 Y=5.402559
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.984375 y=0.728265 X=0.095573 Y=5.388899
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.890625 y=0.721456 X=0.435617 Y=5.369133
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.796875 y=0.711171 X=0.759640 Y=5.341396
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.703125 y=0.695865 X=1.062112 Y=5.304140
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.046875 y=0.722535 X=2.436497 Y=4.902030
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.609375 y=0.673778 X=1.337293 Y=5.256990
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.140625 y=0.686951 X=2.282821 Y=4.965044
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.515625 y=0.644263 X=1.580641 Y=5.201652
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.234375 y=0.643228 X=2.131178 Y=5.023719
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.421875 y=0.613920 X=1.790771 Y=5.141947
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-1.328125 y=0.608305 X=1.971269 Y=5.082049
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.976562 y=0.741120 X=-7.804092 Y=5.429750
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.929688 y=0.741120 X=-7.616594 Y=5.429748
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.882812 y=0.741120 X=-7.429096 Y=5.429747
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.835938 y=0.741119 X=-7.241599 Y=5.429745
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.789062 y=0.741119 X=-7.054103 Y=5.429743
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.742188 y=0.741118 X=-6.866607 Y=5.429741
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.695312 y=0.741117 X=-6.679112 Y=5.429737
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.648438 y=0.741116 X=-6.491619 Y=5.429733
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.601562 y=0.741114 X=-6.304127 Y=5.429729
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.554688 y=0.741112 X=-6.116637 Y=5.429722
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.507812 y=0.741110 X=-5.929150 Y=5.429715
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.460938 y=0.741107 X=-5.741665 Y=5.429705
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.414062 y=0.741104 X=-5.554185 Y=5.429693
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.367188 y=0.741099 X=-5.366709 Y=5.429679
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.320312 y=0.741094 X=-5.179239 Y=5.429661
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.273438 y=0.741087 X=-4.991776 Y=5.429638
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.226562 y=0.741079 X=-4.804321 Y=5.429610
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.179688 y=0.741069 X=-4.616878 Y=5.429576
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.132812 y=0.741056 X=-4.429449 Y=5.429533
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.085938 y=0.741040 X=-4.242037 Y=5.429479
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-3.039062 y=0.741021 X=-4.054646 Y=5.429413
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.992188 y=0.740996 X=-3.867281 Y=5.429331
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.945312 y=0.740966 X=-3.679948 Y=5.429229
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.898438 y=0.740929 X=-3.492656 Y=5.429103
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.851562 y=0.740882 X=-3.305414 Y=5.428946
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.804688 y=0.740824 X=-3.118234 Y=5.428752
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.757812 y=0.740753 X=-2.931131 Y=5.428510
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.710938 y=0.740664 X=-2.744123 Y=5.428212
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.664062 y=0.740553 X=-2.557233 Y=5.427841
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.617188 y=0.740417 X=-2.370490 Y=5.427382
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.570312 y=0.740247 X=-2.183928 Y=5.426813
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.523438 y=0.740036 X=-1.997590 Y=5.426109
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.476562 y=0.739775 X=-1.811530 Y=5.425238
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: logtau=-2.429688 y=0.739451 X=-1.625814 Y=5.424160
# Warning in <TUnfoldDensity::GetRhoIFormMatrix>: Covariance matrix has rank 7 expect 9
# Info in <TUnfoldDensity::ScanTau>: Result logtau=-1.361049 y=0.605207 X=1.910795 Y=5.102918

# %%
# unfolded distribution (histogram)
result = unfold.GetOutput("result")
result.Sumw2()
# Out:
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created

# %%
# -------------------------------------------------------------------------------------
# Get covariance matrices for each uncertainty source
# -------------------------------------------------------------------------------------

# Input statistical uncertainty
mCovInput = unfold.GetEmatrixInput("mCovInput")

# Response matrix statistical uncertainty
mCovMatrix = unfold.GetEmatrixSysUncorr("mCovMatrix")
    
# Total covariance matrix
mCovTot = unfold.GetEmatrixTotal("mCovTot")

# %%
# -------------------------------------------------------------------------------------
# Create relative uncertainty hists from covariance matrices
# -------------------------------------------------------------------------------------

template = result.Clone()
template.Reset()

inputUnc  = template.Clone("inputUnc")
matrixUnc = template.Clone("matrixUnc")
totUnc    = template.Clone("totUnc")

for ibin in xrange(1,result.GetNbinsX()+1):
    inputUnc.SetBinContent(ibin,math.sqrt(mCovInput.GetBinContent(ibin,ibin))/result.GetBinContent(ibin))
    matrixUnc.SetBinContent(ibin,math.sqrt(mCovMatrix.GetBinContent(ibin,ibin))/result.GetBinContent(ibin))
    totUnc.SetBinContent(ibin,math.sqrt(mCovTot.GetBinContent(ibin,ibin))/result.GetBinContent(ibin))

# %%
# -------------------------------------------------------------------------------------
# Plot error breakdown
# -------------------------------------------------------------------------------------

c2 = TCanvas("c2", "", 800, 600)
c2.SetTopMargin(0.08)
c2.SetRightMargin(0.05)
c2.SetBottomMargin(0.14)
c2.SetLeftMargin(0.16)

totUnc.GetXaxis().SetTitle("Top quark p_{T} [GeV]")
totUnc.GetYaxis().SetTitle("Uncertainty [%]")
totUnc.GetYaxis().SetRangeUser(0.0,1.0)
    
c2.cd()
    
totUnc.SetFillColor(17)
totUnc.SetFillStyle(3344)
totUnc.SetLineColor(16)
totUnc.SetLineWidth(2)

inputUnc.SetLineColor(1)
inputUnc.SetLineWidth(2)
inputUnc.SetMarkerColor(1)
inputUnc.SetMarkerStyle(20)

matrixUnc.SetLineColor(2)
matrixUnc.SetLineWidth(2)
matrixUnc.SetMarkerColor(2)
matrixUnc.SetMarkerStyle(34)

leg2 = TLegend(0.2,0.39,0.45,0.88)
leg2.AddEntry(totUnc,   "Total uncertainty","f")
leg2.AddEntry(inputUnc, "Input stat. unc.","lp")
leg2.AddEntry(matrixUnc,"Matrix stat. unc.","lp")
        
leg2.SetFillStyle(0);
leg2.SetBorderSize(0);
leg2.SetTextSize(0.04);
leg2.SetTextFont(42);

totUnc.Draw("hist")
inputUnc.Draw("ep,same")
matrixUnc.Draw("ep,same")

leg2.Draw(); 

c2.Draw()

# %%
# -------------------------------------------------------------------------------------
# Plot covariance matrix
# -------------------------------------------------------------------------------------

c3 = TCanvas("c3", "", 800, 600)
c3.SetTopMargin(0.07)
c3.SetRightMargin(0.12)
c3.SetBottomMargin(0.15)
c3.SetLeftMargin(0.15)

# Normalize covariance matrix
diagonals = []
for ibin in xrange(1,mCovTot.GetNbinsX()+1):
    tmp = math.sqrt(mCovTot.GetBinContent(ibin,ibin)) if (math.sqrt(mCovTot.GetBinContent(ibin,ibin)) is not 0) else 1.0
    diagonals.append(tmp)
for ibinx in xrange(1,mCovTot.GetNbinsX()+1):
    for ibiny in xrange(1,mCovTot.GetNbinsY()+1):
        tmp = mCovTot.GetBinContent(ibinx,ibiny) / diagonals[ibinx-1] / diagonals[ibiny-1]
        mCovTot.SetBinContent(ibinx,ibiny,tmp)

mCovTot.GetZaxis().SetRangeUser(-1.0,1.0)
mCovTot.SetTitle(";unfolded top quark p_{T} [GeV];unfolded top quark p_{T} [GeV]")

mCovTot.Draw("colz")

c3.Draw()

# %%
# -------------------------------------------------------------------------------------
# Translate to cross section (not events) in bins of pt N/L/BR)
# -------------------------------------------------------------------------------------

BR = 0.172 + 0.173 # Branching ratio for semileptonic final state
lum = 35867.0      # 2016 luminosity

expectation.Scale(1.0/(lum*BR)) 
measurement.Scale(1.0/(lum*BR))
result.Scale(1.0/(lum*BR))

# %%
# -------------------------------------------------------------------------------------
# Adjust for bin width
# -------------------------------------------------------------------------------------

for ibin in range(1, result.GetNbinsX()+1 ) :
    width = expectation.GetBinWidth(ibin)
    expectation.SetBinContent(ibin, expectation.GetBinContent(ibin) / width )
    expectation.SetBinError(ibin, expectation.GetBinError(ibin) / width )
    result.SetBinContent(ibin, result.GetBinContent(ibin) / width )
    result.SetBinError(ibin, result.GetBinError(ibin) / width )
    
for ibin in range(1, measurement.GetNbinsX()+1) :  
    width = measurement.GetBinWidth(ibin)
    measurement.SetBinContent(ibin,  measurement.GetBinContent(ibin) / width )
    measurement.SetBinError(ibin,  measurement.GetBinError(ibin) / width )

# %%
     
# -------------------------------------------------------------------------------------
# draw parton-level unfolding
# -------------------------------------------------------------------------------------
    
## ratio of unfolded data to generator-level
ratio = expectation.Clone()
ratio.SetName("ratio")
ratio.SetTitle(";Top quark p_{T} [GeV];Theory/Data")
ratio.Divide(result)
    
# Convert total, statistical uncertainty into error bands
for ibin in xrange(1,expectation.GetNbinsX()+1):
    totUnc.SetBinError(ibin,totUnc.GetBinContent(ibin))
    totUnc.SetBinContent(ibin,1.0)
    inputUnc.SetBinError(ibin,inputUnc.GetBinContent(ibin))
    inputUnc.SetBinContent(ibin,1.0)
        
totUnc.SetMarkerSize(0)
totUnc.SetLineColor(0)
totUnc.SetFillColor(860-9)
totUnc.SetFillStyle(1001)
    
inputUnc.SetMarkerSize(0)
inputUnc.SetLineColor(0)
inputUnc.SetFillColor(18)
inputUnc.SetFillStyle(1001)
    
# Plot
c4 = TCanvas("c3", "", 700, 700)
pad1 =  TPad("pad1","pad1",0,0.3,1,1)
pad1.SetBottomMargin(0.05)
pad1.Draw()
pad1.cd()
    
result.SetMarkerStyle(21)
measurement.SetMarkerStyle(25)
expectation.SetLineColor(4)
expectation.GetYaxis().SetTitleSize(25)
expectation.GetXaxis().SetLabelSize(0)

result.SetTitle(";;d#sigma/dp_{T} [fb/GeV]")
result.GetYaxis().SetTitleOffset(1.2)
result.SetMinimum(0.0)
result.SetAxisRange(0,max(expectation.GetMaximum(),result.GetMaximum())*1.15,"Y")
result.Draw()
expectation.Draw('hist same')
measurement.Draw('same')
    
leg4 = TLegend(0.5, 0.5, 0.9, 0.75)
leg4.SetFillStyle(0)
leg4.SetTextFont(42)
leg4.SetTextSize(0.045)
leg4.SetBorderSize(0)
    
leg4.AddEntry( result, 'Unfolded data', 'p')
leg4.AddEntry( expectation, 'Generator prediction', 'l')
leg4.AddEntry( measurement, 'Measured data', 'p')
leg4.AddEntry( inputUnc, 'Stat. uncertainty','f');
leg4.AddEntry( totUnc, 'Stat. #oplus syst. uncertainties','f');
leg4.Draw()
    
c4.cd()
pad2 =  TPad("pad2","pad2",0,0.0,1,0.28)
pad2.SetTopMargin(0.05)
pad2.SetBottomMargin(0.4)
pad2.Draw()
pad2.cd()
pad2.SetGridy()
ratio.SetMaximum(1.8)
ratio.SetMinimum(0.2)
ratio.UseCurrentStyle()
ratio.GetYaxis().SetTitleSize(25)
ratio.GetYaxis().SetTitleOffset(2.0)
ratio.GetXaxis().SetTitleOffset(4.0)
ratio.GetXaxis().SetLabelSize(25)
ratio.GetYaxis().SetNdivisions(4,4,0,False)
    
ratio.Draw("hist")
totUnc.Draw("same,e2")
inputUnc.Draw("same,e2")
ratio.Draw("same,hist")
    
c4.Update()
c4.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
