# %%
# %%bash
# root -b testUnfold4.C
# Out:
#    ------------------------------------------------------------
#   | Welcome to ROOT 6.10/02                http://root.cern.ch |
#   |                               (c) 1995-2017, The ROOT Team |
#   | Built for macosx64                                         |
#   | From tag v6-10-02, 6 July 2017                             |
#   | Try '.help', '.demo', '.license', '.credits', '.quit'/'.q' |
#    ------------------------------------------------------------
#
#
# Processing testUnfold4.C...
# TUnfold version is V17.6
# toy iteration: 0
# toy iteration: 10
# toy iteration: 20
# toy iteration: 30
# toy iteration: 40
# toy iteration: 50
# toy iteration: 60
# toy iteration: 70
# toy iteration: 80
# toy iteration: 90
# toy iteration: 100
# toy iteration: 110
# toy iteration: 120
# toy iteration: 130
# toy iteration: 140
# toy iteration: 150
# toy iteration: 160
# toy iteration: 170
# toy iteration: 180
# toy iteration: 190
# toy iteration: 200
# toy iteration: 210
# toy iteration: 220
# ...

# %%
from IPython.display import IFrame
IFrame("testUnfold4.png", width=800, height=500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="testUnfold4.png"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
